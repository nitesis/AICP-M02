# %% [markdown]
# # Assignment based on Tutorial II: Fully connected NNs
# Loading Losses and Accuracies in the Final Script for presenting the results of the training in graphs

# %% [markdown]
# ## 1. Load Losses and Accuracies

# %%
import json

# Load results for each model
with open('baseline_results.json', 'r') as f:
    baseline_results = json.load(f)
    
with open('testB_results.json', 'r') as f:
    testB_results = json.load(f)

with open('testC_results.json', 'r') as f:
    testC_results = json.load(f)

with open('testD_results.json', 'r') as f:
    testD_results = json.load(f)

with open('testE_results.json', 'r') as f:
    testE_results = json.load(f)

with open('testF_results.json', 'r') as f:
    testF_results = json.load(f)

with open('testG_results.json', 'r') as f:
    testG_results = json.load(f)

with open('testH_results.json', 'r') as f:
    testH_results = json.load(f)

with open('testI_results.json', 'r') as f:
    testI_results = json.load(f)


# Extract losses and accuracies for plotting
baseline_train_losses = baseline_results['train_losses']
baseline_test_losses = baseline_results['test_losses']
baseline_epoch_accuracies = baseline_results['test_accuracies']  # Corrected key
baseline_final_accuracy = baseline_results['final_accuracy']

testB_train_losses = testB_results['train_losses']
testB_test_losses = testB_results['test_losses']
testB_epoch_accuracies = testB_results['test_accuracies']  # Corrected key
testB_final_accuracy = testB_results['final_accuracy']

testC_train_losses = testC_results['train_losses']
testC_test_losses = testC_results['test_losses']
testC_epoch_accuracies = testC_results['test_accuracies']  # Corrected key
testC_final_accuracy = testC_results['final_accuracy']

testD_train_losses = testD_results['train_losses']
testD_test_losses = testD_results['test_losses']
testD_epoch_accuracies = testD_results['test_accuracies']  # Corrected key
testD_final_accuracy = testD_results['final_accuracy']

testE_train_losses = testE_results['train_losses']
testE_test_losses = testE_results['test_losses']
testE_epoch_accuracies = testE_results['test_accuracies']  # Corrected key
testE_final_accuracy = testE_results['final_accuracy']

testF_train_losses = testF_results['train_losses']
testF_test_losses = testF_results['test_losses']
testF_epoch_accuracies = testF_results['test_accuracies']  # Corrected key
testF_final_accuracy = testF_results['final_accuracy']

testG_train_losses = testG_results['train_losses']
testG_test_losses = testG_results['test_losses']
testG_epoch_accuracies = testG_results['test_accuracies']  # Corrected key
testG_final_accuracy = testG_results['final_accuracy']

testH_train_losses = testH_results['train_losses']
testH_test_losses = testH_results['test_losses']
testH_epoch_accuracies = testH_results['test_accuracies']  # Corrected key
testH_final_accuracy = testH_results['final_accuracy']

testI_train_losses = testI_results['train_losses']
testI_test_losses = testI_results['test_losses']
testI_epoch_accuracies = testI_results['test_accuracies']  # Corrected key
testI_final_accuracy = testI_results['final_accuracy']

# %% [markdown]
# ## 2. Plotting the Epoch Losses

# %%
import matplotlib.pyplot as plt

# 10 epochs for all models
epochs = list(range(1, 11))

plt.figure(figsize=(10, 5))

# Plot losses for the baseline model
plt.plot(epochs, baseline_train_losses, label='Baseline - Train Loss')
plt.plot(epochs, baseline_test_losses, label='Baseline - Test Loss')

# Plot losses for Test B model
plt.plot(epochs, testB_train_losses, label='Test B - Train Loss')
plt.plot(epochs, testB_test_losses, label='Test B - Test Loss')

# Plot losses for Test C model
plt.plot(epochs, testC_train_losses, label='Test C - Train Loss')
plt.plot(epochs, testC_test_losses, label='Test C - Test Loss')

# Plot losses for Test D model
plt.plot(epochs, testD_train_losses, label='Test D - Train Loss')
plt.plot(epochs, testD_test_losses, label='Test D - Test Loss')

# Plot losses for Test E model
plt.plot(epochs, testE_train_losses, label='Test E - Train Loss')
plt.plot(epochs, testE_test_losses, label='Test E - Test Loss')

# Plot losses for Test F model
plt.plot(epochs, testF_train_losses, label='Test F - Train Loss')
plt.plot(epochs, testF_test_losses, label='Test F - Test Loss')

# Plot losses for Test G model
plt.plot(epochs, testG_train_losses, label='Test G - Train Loss')
plt.plot(epochs, testG_test_losses, label='Test G - Test Loss')

# Plot losses for Test H model
plt.plot(epochs, testH_train_losses, label='Test H - Train Loss')
plt.plot(epochs, testH_test_losses, label='Test H - Test Loss')

# Plot losses for Test I model
plt.plot(epochs, testI_train_losses, label='Test I - Train Loss')
plt.plot(epochs, testI_test_losses, label='Test I - Test Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Losses Over Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Plotting the Epoch Losses

# %%
import matplotlib.pyplot as plt

# 10 epochs for all models
epochs = list(range(1, 11))

plt.figure(figsize=(10, 5))

# Plot losses for the baseline model
plt.plot(epochs, baseline_train_losses, label='Baseline - Train Loss')
plt.plot(epochs, baseline_test_losses, label='Baseline - Test Loss')

# Plot losses for Test B model
plt.plot(epochs, testB_train_losses, label='Test B - Train Loss')
plt.plot(epochs, testB_test_losses, label='Test B - Test Loss')

# Plot losses for Test C model
plt.plot(epochs, testC_train_losses, label='Test C - Train Loss')
plt.plot(epochs, testC_test_losses, label='Test C - Test Loss')

# Plot losses for Test D model
plt.plot(epochs, testD_train_losses, label='Test D - Train Loss')
plt.plot(epochs, testD_test_losses, label='Test D - Test Loss')

# Plot losses for Test E model
plt.plot(epochs, testE_train_losses, label='Test E - Train Loss')
plt.plot(epochs, testE_test_losses, label='Test E - Test Loss')

# Plot losses for Test F model
plt.plot(epochs, testF_train_losses, label='Test F - Train Loss')
plt.plot(epochs, testF_test_losses, label='Test F - Test Loss')

# Plot losses for Test G model
plt.plot(epochs, testF_train_losses, label='Test G - Train Loss')
plt.plot(epochs, testF_test_losses, label='Test G - Test Loss')

# Plot losses for Test H model
plt.plot(epochs, testH_train_losses, label='Test H - Train Loss')
plt.plot(epochs, testH_test_losses, label='Test H - Test Loss')

# Plot losses for Test I model
plt.plot(epochs, testI_train_losses, label='Test I - Train Loss')
plt.plot(epochs, testI_test_losses, label='Test I - Test Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Losses Over Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Plotting the Epoch Accuracies (Accuracy Over Epochs)

# %%
plt.figure(figsize=(10, 5))

# Plot accuracies for the baseline model
plt.plot(epochs, baseline_epoch_accuracies, label='Baseline - Accuracy')

# Plot accuracies for Test B model
plt.plot(epochs, testB_epoch_accuracies, label='Test B - Accuracy')

# Plot accuracies for Test C model
plt.plot(epochs, testC_epoch_accuracies, label='Test C - Accuracy')

# Plot accuracies for Test D model
plt.plot(epochs, testD_epoch_accuracies, label='Test D - Accuracy')

# Plot accuracies for Test E model
plt.plot(epochs, testE_epoch_accuracies, label='Test E - Accuracy')

# Plot accuracies for Test F model
plt.plot(epochs, testF_epoch_accuracies, label='Test F - Accuracy')

# Plot accuracies for Test G model
plt.plot(epochs, testG_epoch_accuracies, label='Test G - Accuracy')

# Plot accuracies for Test H model
plt.plot(epochs, testH_epoch_accuracies, label='Test H - Accuracy')

# Plot accuracies for Test I model
plt.plot(epochs, testI_epoch_accuracies, label='Test I - Accuracy')


plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracies Over Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Plotting the Final Accuracies (Third Graph)

# %%
# List of model names and their final accuracies
model_names = ['Baseline', 'Test B', 'Test C', 'Test D', 'Test E', 'Test F', 'Test G', 'Test H','Test I']
final_accuracies = [baseline_final_accuracy, testB_final_accuracy, testC_final_accuracy, testD_final_accuracy, testE_final_accuracy, testF_final_accuracy, testG_final_accuracy, testH_final_accuracy,testI_final_accuracy]


plt.figure(figsize=(8, 5))
plt.bar(model_names, final_accuracies)
plt.xlabel('Model')
plt.ylabel('Final Accuracy')
plt.title('Final Accuracy of Each Model')
plt.show()

# %% [markdown]
# ## 5. Loss differences between training and testing

# %% [markdown]
# Why: These plots help to see how big the differences between the training and test values are. Large differences can indicate overfitting.
# Plot: Line graph showing the difference between training and testing for losses.

# %%
import numpy as np

# Calculate the difference between train and test losses for each model
baseline_loss_diff = np.array(baseline_train_losses) - np.array(baseline_test_losses)
testB_loss_diff = np.array(testB_train_losses) - np.array(testB_test_losses)
testC_loss_diff = np.array(testC_train_losses) - np.array(testC_test_losses)
testD_loss_diff = np.array(testD_train_losses) - np.array(testD_test_losses)
testE_loss_diff = np.array(testE_train_losses) - np.array(testE_test_losses)
testF_loss_diff = np.array(testF_train_losses) - np.array(testF_test_losses)
testG_loss_diff = np.array(testG_train_losses) - np.array(testG_test_losses)
testH_loss_diff = np.array(testH_train_losses) - np.array(testH_test_losses)
testI_loss_diff = np.array(testI_train_losses) - np.array(testI_test_losses)

# Plot the differences
plt.plot(baseline_loss_diff, label="Baseline Loss Difference")
plt.plot(testB_loss_diff, label="TestB Loss Difference")
plt.plot(testC_loss_diff, label="TestC Loss Difference")
plt.plot(testD_loss_diff, label="TestD Loss Difference")
plt.plot(testE_loss_diff, label="TestE Loss Difference")
plt.plot(testF_loss_diff, label="TestF Loss Difference")
plt.plot(testG_loss_diff, label="TestG Loss Difference")
plt.plot(testH_loss_diff, label="TestH Loss Difference")
plt.plot(testI_loss_diff, label="TestI Loss Difference")

# Labels and title
plt.xlabel("Epochs")
plt.ylabel("Loss Difference (Train - Test)")
plt.legend()
plt.title("Loss Difference between Train and Test over Epochs")
plt.show()

# %% [markdown]
# ## 6. Confusion matrix
# Why: A very useful plot to see which classes are frequently confused. This helps to understand how the model performs with specific classes.
# Plot: Confusion matrix (in a heatmap format) based on the test data of the best model.

# %%
# from sklearn.metrics import confusion_matrix
# import seaborn as sns

# y_true = [...]  # Die echten Labels deiner Testdaten
# y_pred = [...]  # Die Vorhersagen deines Modells auf den Testdaten

# cm = confusion_matrix(y_true, y_pred)
# sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
# plt.xlabel("Predicted")
# plt.ylabel("True")
# plt.title("Confusion Matrix")
# plt.show()

# %% [markdown]
# ## 7. Model training time per epoch

# %% [markdown]
# Why: If you have recorded the training time per epoch for different models, you can compare the efficiency and performance of the models.
# Plot: Bar chart showing the training times per epoch for different models.

# %%
time_per_epoch_baseline = baseline_results['time_per_epoch']
time_per_epochB = testB_results['time_per_epoch']
time_per_epochC = testC_results['time_per_epoch']
time_per_epochD = testD_results['time_per_epoch']
time_per_epochE = testE_results['time_per_epoch']
time_per_epochF = testF_results['time_per_epoch']
time_per_epochG = testG_results['time_per_epoch']
time_per_epochH = testH_results['time_per_epoch']
time_per_epochI = testI_results['time_per_epoch']

# Plotten der Zeiten für alle Modelle
plt.plot(time_per_epoch_baseline, label="time_per_epoch")
plt.plot(time_per_epochB, label="time_per_epochF")
plt.plot(time_per_epochC, label="time_per_epochF")
plt.plot(time_per_epochD, label="time_per_epochF")
plt.plot(time_per_epochE, label="time_per_epochF")
plt.plot(time_per_epochF, label="time_per_epochF")
plt.plot(time_per_epochF, label="time_per_epochF")
plt.plot(time_per_epochG, label="time_per_epochG")
plt.plot(time_per_epochH, label="time_per_epochH")
plt.plot(time_per_epochI, label="time_per_epochI")
plt.ylabel("Time (seconds)")
plt.title("Training Time per Epoch Comparison")
plt.legend()
plt.show()

# %%
## 8. Model evaluation: Accuracy vs Overfitting Risk

# %% [markdown]
# Why: To identify the model that balances both high accuracy and low train/test loss difference, ensuring good performance and generalization.
# Plot:  Scatter plot showing final accuracy vs. train/test loss difference for different models.

# %% [markdown]
#  Calculate Final Loss Differences

# %%
# Calculate the final loss difference for each model
baseline_final_loss_diff = baseline_train_losses[-1] - baseline_test_losses[-1]
testB_final_loss_diff = testB_train_losses[-1] - testB_test_losses[-1]
testC_final_loss_diff = testC_train_losses[-1] - testC_test_losses[-1]
testD_final_loss_diff = testD_train_losses[-1] - testD_test_losses[-1]
testE_final_loss_diff = testE_train_losses[-1] - testE_test_losses[-1]
testF_final_loss_diff = testF_train_losses[-1] - testF_test_losses[-1]
testG_final_loss_diff = testG_train_losses[-1] - testG_test_losses[-1]
testH_final_loss_diff = testH_train_losses[-1] - testH_test_losses[-1]
testI_final_loss_diff = testI_train_losses[-1] - testI_test_losses[-1]  # Corrected

# List of final loss differences
final_loss_diffs = [baseline_final_loss_diff, testB_final_loss_diff, testC_final_loss_diff, 
                    testD_final_loss_diff, testE_final_loss_diff, testF_final_loss_diff, 
                    testG_final_loss_diff, testH_final_loss_diff, testI_final_loss_diff]

# %% [markdown]
# Create a Scatter Plot Comparing Final Accuracy and Loss Differences

# %%
import matplotlib.pyplot as plt

# List of model names and their final accuracies
model_names = ['Baseline', 'Test B', 'Test C', 'Test D', 'Test E', 'Test F', 'Test G', 'Test H','Test I']
final_accuracies = [baseline_final_accuracy, testB_final_accuracy, testC_final_accuracy, testD_final_accuracy, 
                    testE_final_accuracy, testF_final_accuracy, testG_final_accuracy, testH_final_accuracy,testI_final_accuracy]

# Scatter plot of final accuracy (x-axis) vs final loss difference (y-axis)
plt.figure(figsize=(8, 5))
plt.scatter(final_accuracies, final_loss_diffs)

# Annotate each point with the corresponding model name
for i, model_name in enumerate(model_names):
    plt.annotate(model_name, (final_accuracies[i], final_loss_diffs[i]))

# Add labels and title
plt.xlabel('Final Accuracy')
plt.ylabel('Final Train-Test Loss Difference')
plt.title('Comparison of Models: Accuracy vs Train-Test Loss Difference')
plt.grid(True)
plt.show()

# %% [markdown]
# H and I perform best with high overall accuracy and nearly zero diff between training and test loss.
